# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import help_functions as hf

# %% [markdown]
# # Catching movie rating

# %%
# Loading dataframe stored in pickle file
data = hf.load_data_pickle('dataframe_disney_cleaned.pickle')
print(data[0:5])
# Out:
#                              title       Production company  \
# 0          Academy Award Review of  Walt Disney Productions
# 1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2                        Pinocchio  Walt Disney Productions
# 3                         Fantasia  Walt Disney Productions
# 4             The Reluctant Dragon  Walt Disney Productions
#
#        Distributed by Release date  Running time        Country Language  \
# 0      United Artists   1937-05-19            41  United States  English
# 1  RKO Radio Pictures          NaT            83  United States  English
# 2  RKO Radio Pictures          NaT            88  United States  English
# 3  RKO Radio Pictures   1940-11-13           126  United States  English
# 4  RKO Radio Pictures   1941-06-27            74  United States  English
#
#    Box office                                        Directed by  \
# 0        45.0                                                NaN
# 1       418.0  [David Hand, William Cottrell, Wilfred Jackson...
# 2       164.0  [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 3        76.0  [Samuel Armstrong, James Algar, Bill Roberts, ...
# 4       960.0  Alfred Werker (live action) Hamilton Luske (an...
#
#                                           Written by  ... Original concept by  \
# 0                                                NaN  ...                 NaN
# 1  [Ted Sears, Richard Creedon, Otto Englander, D...  ...                 NaN
# 2                                                NaN  ...                 NaN
# 3                                                NaN  ...                 NaN
# 4  Live-action: Ted Sears Al Perkins Larry Clemmo...  ...                 NaN
#
#   Music Lyrics Book Basis Productions Awards Created by Original work Owner
# 0   NaN    NaN  NaN   NaN         NaN    NaN        NaN           NaN   NaN
# 1   NaN    NaN  NaN   NaN         NaN    NaN        NaN           NaN   NaN
# 2   NaN    NaN  NaN   NaN         NaN    NaN        NaN           NaN   NaN
# 3   NaN    NaN  NaN   NaN         NaN    NaN        NaN           NaN   NaN
# 4   NaN    NaN  NaN   NaN         NaN    NaN        NaN           NaN   NaN
#
# [5 rows x 43 columns]

# %%
# Transforming the DataFrame into a Pandas DataFrame
df = pd.DataFrame(data)
# Creating a year column in the dataframe, so that the catch_movie() function runs more accurately, selecting the correct year and not the same movie from another year.
df['Release Year'] = df['Release date'].dt.year.astype('Int64')
df['Release Year']
# Out:
# 0      1937
# 1      <NA>
# 2      <NA>
# 3      1940
# 4      1941
#        ...
# 514    1986
# 516    <NA>
# 517    1963
# 518    <NA>
# 519    1991
# Name: Release Year, Length: 499, dtype: Int64

# %%
# Create a column named ['Rotten Tomatoes'], where from the catch_movie() function is used as parameter 'Rotten Tomatoes' to return the review score of this site
df['Rotten Tomatoes'] = df.apply(lambda x:hf.catch_rating(x['title'], x['Release Year'],'Rotten Tomatoes' ), axis=1)

# Creates a column called ['Internet Movie Database'], where from the catch_movie() function is used as parameter 'Internet Movie Database' to return the review note of this site
df['Internet Movie Database'] = df.apply(lambda x:hf.catch_rating(x['title'], x['Release Year'], 'Internet Movie Database' ), axis=1)

# Creates a column named ['Metacritic'], where from the catch_movie() function is used as parameter 'Metacritic'] to return the review note of this site
df['Metacritic'] = df.apply(lambda x:hf.catch_rating(x['title'], x['Release Year'],'Metacritic' ), axis=1)

# %%
data = df[['title', 'Release date','Rotten Tomatoes','Internet Movie Database','Metacritic']]
data
# Out:
#                                title Release date Rotten Tomatoes  \
# 0            Academy Award Review of   1937-05-19               0
# 1    Snow White and the Seven Dwarfs          NaT               0
# 2                          Pinocchio          NaT               0
# 3                           Fantasia   1940-11-13              95
# 4               The Reluctant Dragon   1941-06-27               0
# ..                               ...          ...             ...
# 514                        SpaceCamp   1986-06-06              46
# 516                   The Aristocats          NaT               0
# 517           The Sword in the Stone   1963-12-25              66
# 518                      Tinker Bell          NaT               0
# 519                    The Rocketeer   1991-06-21              66
#
#     Internet Movie Database Metacritic
# 0                       7.1          0
# 1                         0          0
# 2                         0          0
# 3                       7.7         96
# 4                       6.8          0
# ..                      ...        ...
# 514                     5.7         40
# 516                       0          0
# 517                     7.2         61
# 518                       0          0
# 519                     6.5         61
#
# [499 rows x 5 columns]

# %%
# Deleting lines with title == 0
data.drop(data.loc[df['title'] =='0'].index, inplace=True)
data.head()
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_4820\3905235049.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(data.loc[df['title'] =='0'].index, inplace=True)
#                              title Release date Rotten Tomatoes  \
# 0          Academy Award Review of   1937-05-19               0
# 1  Snow White and the Seven Dwarfs          NaT               0
# 2                        Pinocchio          NaT               0
# 3                         Fantasia   1940-11-13              95
# 4             The Reluctant Dragon   1941-06-27               0
#
#   Internet Movie Database Metacritic
# 0                     7.1          0
# 1                       0          0
# 2                       0          0
# 3                     7.7         96
# 4                     6.8          0

# %%
data.to_csv('dataframe_disney_imdb_note.csv')

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499 entries, 0 to 519
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    499 non-null    object
#  1   Release date             276 non-null    datetime64[ns]
#  2   Rotten Tomatoes          499 non-null    object
#  3   Internet Movie Database  499 non-null    object
#  4   Metacritic               499 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 23.4+ KB
# C:\Users\Diego\AppData\Local\Temp\ipykernel_4820\1879732367.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe()
#            title         Release date  Rotten Tomatoes  \
# count        499                  276            499.0
# unique       472                  268             80.0
# top     Hercules  2019-11-12 00:00:00              0.0
# freq           2                    2            312.0
# first        NaN  1937-05-19 00:00:00              NaN
# last         NaN  2022-04-22 00:00:00              NaN
#
#         Internet Movie Database  Metacritic
# count                     499.0       499.0
# unique                     47.0        62.0
# top                         0.0         0.0
# freq                      241.0       340.0
# first                       NaN         NaN
# last                        NaN         NaN

# %%
df
# Out:
#                                title       Production company  \
# 0            Academy Award Review of  Walt Disney Productions
# 1    Snow White and the Seven Dwarfs  Walt Disney Productions
# 2                          Pinocchio  Walt Disney Productions
# 3                           Fantasia  Walt Disney Productions
# 4               The Reluctant Dragon  Walt Disney Productions
# ..                               ...                      ...
# 514                        SpaceCamp      ABC Motion Pictures
# 516                   The Aristocats  Walt Disney Productions
# 517           The Sword in the Stone  Walt Disney Productions
# 518                      Tinker Bell       DisneyToon Studios
# 519                    The Rocketeer                      NaN
#
#                              Distributed by Release date  Running time  \
# 0                            United Artists   1937-05-19            41
# 1                        RKO Radio Pictures          NaT            83
# 2                        RKO Radio Pictures          NaT            88
# 3                        RKO Radio Pictures   1940-11-13           126
# 4                        RKO Radio Pictures   1941-06-27            74
# ..                                      ...          ...           ...
# 514                        20th Century Fox   1986-06-06           107
# 516                Buena Vista Distribution          NaT            79
# 517                Buena Vista Distribution   1963-12-25            74
# 518  Walt Disney Studios Home Entertainment          NaT           468
# 519       Buena Vista Pictures Distribution   1991-06-21           108
#
#            Country Language  Box office  \
# 0    United States  English        45.0
# 1    United States  English       418.0
# 2    United States  English       164.0
# 3    United States  English        76.0
# 4    United States  English       960.0
# ..             ...      ...         ...
# 514  United States  English         9.0
# 516  United States  English       191.0
# 517  United States  English        22.0
# 518  United States  English         NaN
# 519  United States  English        46.0
#
#                                            Directed by  \
# 0                                                  NaN
# 1    [David Hand, William Cottrell, Wilfred Jackson...
# 2    [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 3    [Samuel Armstrong, James Algar, Bill Roberts, ...
# 4    Alfred Werker (live action) Hamilton Luske (an...
# ..                                                 ...
# 514                                        Harry Winer
# 516                                Wolfgang Reitherman
# 517  [Wolfgang Reitherman, Hamilton Luske (Uncredit...
# 518  [Bradley Raymond ( 1 , 3 & 4 ), Klay Hall ( 2 ...
# 519                                       Joe Johnston
#
#                                             Written by  ... Basis Productions  \
# 0                                                  NaN  ...   NaN         NaN
# 1    [Ted Sears, Richard Creedon, Otto Englander, D...  ...   NaN         NaN
# 2                                                  NaN  ...   NaN         NaN
# 3                                                  NaN  ...   NaN         NaN
# 4    Live-action: Ted Sears Al Perkins Larry Clemmo...  ...   NaN         NaN
# ..                                                 ...  ...   ...         ...
# 514                                                NaN  ...   NaN         NaN
# 516                                                NaN  ...   NaN         NaN
# 517                                                NaN  ...   NaN         NaN
# 518                                                NaN  ...   NaN         NaN
# 519                                                NaN  ...   NaN         NaN
#
#     Awards Created by Original work Owner Release Year Rotten Tomatoes  \
# 0      NaN        NaN           NaN   NaN         1937               0
# 1      NaN        NaN           NaN   NaN         <NA>               0
# 2      NaN        NaN           NaN   NaN         <NA>               0
# 3      NaN        NaN           NaN   NaN         1940              95
# 4      NaN        NaN           NaN   NaN         1941               0
# ..     ...        ...           ...   ...          ...             ...
# 514    NaN        NaN           NaN   NaN         1986              46
# 516    NaN        NaN           NaN   NaN         <NA>               0
# 517    NaN        NaN           NaN   NaN         1963              66
# 518    NaN        NaN           NaN   NaN         <NA>               0
# 519    NaN        NaN           NaN   NaN         1991              66
#
#     Internet Movie Database Metacritic
# 0                       7.1          0
# 1                         0          0
# 2                         0          0
# 3                       7.7         96
# 4                       6.8          0
# ..                      ...        ...
# 514                     5.7         40
# 516                       0          0
# 517                     7.2         61
# 518                       0          0
# 519                     6.5         61
#
# [499 rows x 47 columns]
